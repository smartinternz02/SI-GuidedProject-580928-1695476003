# %%
import numpy as np
import pandas as pd

# %%
# Task-1
data = np.random.rand(4, 4)

df = pd.DataFrame(data, columns=['f1', 'f2', 'f3', 'f4'])
df
# Out:
#          f1        f2        f3        f4
# 0  0.546351  0.902036  0.114934  0.574489
# 1  0.635666  0.634721  0.774360  0.042700
# 2  0.351733  0.423870  0.489962  0.434681
# 3  0.022290  0.292108  0.732018  0.448149

# %%
# Task-2

df.columns = ['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.546351        0.902036        0.114934        0.574489
# 1        0.635666        0.634721        0.774360        0.042700
# 2        0.351733        0.423870        0.489962        0.434681
# 3        0.022290        0.292108        0.732018        0.448149

# %%
# Task-3

df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.389010        0.563184        0.527819        0.375005
# std          0.271704        0.266351        0.302427        0.230313
# min          0.022290        0.292108        0.114934        0.042700
# 25%          0.269372        0.390930        0.396205        0.336685
# 50%          0.449042        0.529295        0.610990        0.441415
# 75%          0.568679        0.701550        0.742603        0.479734
# max          0.635666        0.902036        0.774360        0.574489

# %%
# Task-4

df.dtypes
# Out:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
# Task-5

df.loc[:, ['Random value 2','Random value 3']]
# Out:
#    Random value 2  Random value 3
# 0        0.902036        0.114934
# 1        0.634721        0.774360
# 2        0.423870        0.489962
# 3        0.292108        0.732018

# %%
df.iloc[:,[1,2]]
# Out:
#    Random value 2  Random value 3
# 0        0.902036        0.114934
# 1        0.634721        0.774360
# 2        0.423870        0.489962
# 3        0.292108        0.732018
